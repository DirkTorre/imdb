# %%
import os
import time
import numpy as np
import pandas as pd

# %%
START_TIME = time.time()

BASE_URL = "https://datasets.imdbws.com/"

FILES_IMDB = {
    "tit_bas": "title.basics.tsv",
    "tit_rate": "title.ratings.tsv",
    "name_bas": "name.basics.tsv",
    "cast_crew": "title.principals.tsv",
}

FILES_HAND = {
    "add_seen": "add_movies_seen.txt",
    "add_unseen": "add_movies_unseen.txt",
    "add_secop": "add_movies_second_opinion.txt",
    "raw_status": "raw_status.xlsx"
}

FILES_GENERATED = {
    "films_raw": os.path.join("data", "generated", "films_raw.pkl"),
    "films_readable": os.path.join("data", "generated", "films_reading.xlsx"),
    "films_mining": os.path.join("data", "generated", "films_mining.xlsx")
}

# %%
raw_film_data = pd.read_pickle(FILES_GENERATED["films_raw"])

# %%
raw_film_data
# Out:
#          tconst  watched watched_date  netflix  prime  enjoyment  priority  \
# 0     tt0015324    False          NaT     <NA>   <NA>        NaN       NaN
# 1     tt0015324    False          NaT     <NA>   <NA>        NaN       NaN
# 2     tt0015324    False          NaT     <NA>   <NA>        NaN       NaN
# 3     tt0015324    False          NaT     <NA>   <NA>        NaN       NaN
# 4     tt0015324    False          NaT     <NA>   <NA>        NaN       NaN
# ...         ...      ...          ...      ...    ...        ...       ...
# 6114  tt9806192     True          NaT     <NA>   <NA>        4.0       NaN
# 6115  tt9806192     True          NaT     <NA>   <NA>        4.0       NaN
# 6116  tt9806192     True          NaT     <NA>   <NA>        4.0       NaN
# 6117  tt9806192     True          NaT     <NA>   <NA>        4.0       NaN
# 6118  tt9806192     True          NaT     <NA>   <NA>        4.0       NaN
#
#      titleType    primaryTitle         originalTitle  ... averageRating  \
# 0        movie    Sherlock Jr.          Sherlock Jr.  ...           8.2
# 1        movie    Sherlock Jr.          Sherlock Jr.  ...           8.2
# 2        movie    Sherlock Jr.          Sherlock Jr.  ...           8.2
# 3        movie    Sherlock Jr.          Sherlock Jr.  ...           8.2
# 4        movie    Sherlock Jr.          Sherlock Jr.  ...           8.2
# ...        ...             ...                   ...  ...           ...
# 6114     movie  I Lost My Body  J'ai perdu mon corps  ...           7.5
# 6115     movie  I Lost My Body  J'ai perdu mon corps  ...           7.5
# 6116     movie  I Lost My Body  J'ai perdu mon corps  ...           7.5
# 6117     movie  I Lost My Body  J'ai perdu mon corps  ...           7.5
# 6118     movie  I Lost My Body  J'ai perdu mon corps  ...           7.5
#
#      numVotes ordering     nconst         category                      job  \
# 0       51136       10  nm0504380  cinematographer                      NaN
# 1       51136        1  nm0000036            actor                      NaN
# 2       51136        2  nm0570230          actress                      NaN
# 3       51136        3  nm0444172            actor                      NaN
# 4       51136        4  nm0175068            actor                      NaN
# ...       ...      ...        ...              ...                      ...
# 6114    33775        5  nm3021346         director                      NaN
# 6115    33775        6  nm0491011           writer  adaptation and dialogue
# 6116    33775        7  nm0238941         producer                 producer
# 6117    33775        8  nm1776887         composer                      NaN
# 6118    33775        9  nm1928263           editor                      NaN
#
#              primaryName  birthYear deathYear  \
# 0          Elgin Lessley       1883      1944
# 1          Buster Keaton       1895      1966
# 2        Kathryn McGuire       1903      1978
# 3             Joe Keaton       1867      1946
# 4         Erwin Connelly       1878      1931
# ...                  ...        ...       ...
# 6114       Jérémy Clapin       1974      <NA>
# 6115   Guillaume Laurant       1961      <NA>
# 6116   Marc Du Pontavice       <NA>      <NA>
# 6117            Dan Levy       1976      <NA>
# 6118  Benjamin Massoubre       <NA>      <NA>
#
#                                primaryProfession
# 0                          cinematographer,actor
# 1                          actor,writer,director
# 2                                        actress
# 3                                          actor
# 4                                          actor
# ...                                          ...
# 6114                      writer,director,editor
# 6115                                writer,actor
# 6116          producer,production_manager,writer
# 6117        soundtrack,composer,music_department
# 6118  editor,editorial_department,visual_effects
#
# [6119 rows x 25 columns]

# %%
staff = raw_film_data.loc[:,['tconst','nconst','category','primaryName','birthYear','deathYear']]
staff.loc[:,'printname'] = staff.loc[:,'primaryName'] + " " + staff.loc[:,'birthYear'].astype('str') + ' - ' + staff.loc[:,'deathYear'].astype(str)
staff.drop(['nconst','primaryName','birthYear','deathYear'], axis=1, inplace=True)
staff = staff.groupby(['tconst','category'])['printname'].aggregate(lambda x: tuple(x)).unstack()

genres = raw_film_data.loc[:,['tconst','genres']].drop_duplicates()
genres.genres = genres.genres.str.split(',')
genres = genres.explode('genres')
genres['value'] = 1
genres = pd.pivot_table(genres.explode('genres'), values='value', index='tconst', columns='genres', fill_value=0)

readable_data = raw_film_data.copy()
readable_data.drop(['isAdult','ordering', 'nconst','category','job','primaryName','birthYear','deathYear', 'genres','endYear','primaryProfession'], axis=1, inplace=True)
readable_data.drop_duplicates(inplace=True)
readable_data = pd.merge(readable_data, genres, on="tconst", how="left")
readable_data = pd.merge(readable_data, staff, on="tconst", how="left")
readable_data.loc[:,'watched'] = readable_data.loc[:,'watched'].replace(True,1).replace(False,0)
readable_data.head()
# Out:
#       tconst  watched watched_date  netflix  prime  enjoyment  priority  \
# 0  tt0015324        0          NaT     <NA>   <NA>        NaN       NaN
# 1  tt0017136        0          NaT        0      0        NaN       NaN
# 2  tt0022100        0          NaT        0      0        NaN       NaN
# 3  tt0025316        0          NaT     <NA>   <NA>        NaN       NaN
# 4  tt0031381        0          NaT     <NA>   <NA>        NaN       NaN
#
#   titleType           primaryTitle                      originalTitle  ...  \
# 0     movie           Sherlock Jr.                       Sherlock Jr.  ...
# 1     movie             Metropolis                         Metropolis  ...
# 2     movie                      M  M - Eine Stadt sucht einen Mörder  ...
# 3     movie  It Happened One Night              It Happened One Night  ...
# 4     movie     Gone with the Wind                 Gone with the Wind  ...
#
#                                              actress archive_footage  \
# 0                     (Kathryn McGuire 1903 - 1978,)             NaN
# 1                       (Brigitte Helm 1906 - 1996,)             NaN
# 2  (Ellen Widmann 1894 - 1985, Inge Landgut 1922 ...             NaN
# 3                   (Claudette Colbert 1903 - 1996,)             NaN
# 4  (Vivien Leigh 1913 - 1967, Barbara O'Neil 1910...             NaN
#
#                                      cinematographer  \
# 0  (Elgin Lessley 1883 - 1944, Byron Houck 1891 -...
# 1                                                NaN
# 2                   (Fritz Arno Wagner 1894 - 1958,)
# 3                       (Joseph Walker 1892 - 1985,)
# 4                                                NaN
#
#                                             composer  \
# 0                 (Club Foot Orchestra <NA> - <NA>,)
# 1  (Sandro Forte 1970 - 2020, Maximianno Cobra 19...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                             director  \
# 0                                                NaN
# 1                          (Fritz Lang 1890 - 1976,)
# 2                          (Fritz Lang 1890 - 1976,)
# 3                         (Frank Capra 1897 - 1991,)
# 4  (Victor Fleming 1889 - 1949, George Cukor 1899...
#
#                            editor                     producer  \
# 0                             NaN                          NaN
# 1                             NaN  (Erich Pommer 1889 - 1966,)
# 2  (Paul Falkenberg 1903 - 1986,)                          NaN
# 3     (Gene Havlick 1894 - 1959,)                          NaN
# 4                             NaN                          NaN
#
#    production_designer  self  \
# 0                  NaN   NaN
# 1                  NaN   NaN
# 2                  NaN   NaN
# 3                  NaN   NaN
# 4                  NaN   NaN
#
#                                               writer
# 0  (Jean C. Havez 1872 - 1925, Joseph A. Mitchell...
# 1                     (Thea von Harbou 1888 - 1954,)
# 2  (Thea von Harbou 1888 - 1954, Egon Jacobsohn 1...
# 3  (Robert Riskin 1897 - 1955, Samuel Hopkins Ada...
# 4  (Oliver H.P. Garrett 1894 - 1952, Margaret Mit...
#
# [5 rows x 48 columns]

# %%
import os
import time
import numpy as np
import pandas as pd

# %%
START_TIME = time.time()

BASE_URL = "https://datasets.imdbws.com/"

FILES_IMDB = {
    "tit_bas": "title.basics.tsv",
    "tit_rate": "title.ratings.tsv",
    "name_bas": "name.basics.tsv",
    "cast_crew": "title.principals.tsv",
}

FILES_HAND = {
    "add_seen": "add_movies_seen.txt",
    "add_unseen": "add_movies_unseen.txt",
    "add_secop": "add_movies_second_opinion.txt",
    "raw_status": "raw_status.xlsx"
}

FILES_GENERATED = {
    "films_raw": os.path.join("data", "generated", "films_raw.pkl"),
    "films_readable": os.path.join("data", "generated", "films_reading.xlsx"),
    "films_mining": os.path.join("data", "generated", "films_mining.xlsx")
}

# %%
raw_film_data = pd.read_pickle(FILES_GENERATED["films_raw"])

# %%
raw_film_data
# Out:
#           tconst  watched watched_date  netflix  prime  enjoyment  priority  \
# 0      tt0015324    False          NaT     <NA>   <NA>        NaN       NaN
# 1      tt0015324    False          NaT     <NA>   <NA>        NaN       NaN
# 2      tt0015324    False          NaT     <NA>   <NA>        NaN       NaN
# 3      tt0015324    False          NaT     <NA>   <NA>        NaN       NaN
# 4      tt0015324    False          NaT     <NA>   <NA>        NaN       NaN
# ...          ...      ...          ...      ...    ...        ...       ...
# 71987  tt9806192     True          NaT     <NA>   <NA>        4.0       NaN
# 71988  tt9806192     True          NaT     <NA>   <NA>        4.0       NaN
# 71989  tt9806192     True          NaT     <NA>   <NA>        4.0       NaN
# 71990  tt9806192     True          NaT     <NA>   <NA>        4.0       NaN
# 71991  tt9806192     True          NaT     <NA>   <NA>        4.0       NaN
#
#       titleType    primaryTitle         originalTitle  ... numVotes ordering  \
# 0         movie    Sherlock Jr.          Sherlock Jr.  ...    51213       10
# 1         movie    Sherlock Jr.          Sherlock Jr.  ...    51213       10
# 2         movie    Sherlock Jr.          Sherlock Jr.  ...    51213       10
# 3         movie    Sherlock Jr.          Sherlock Jr.  ...    51213       10
# 4         movie    Sherlock Jr.          Sherlock Jr.  ...    51213       10
# ...         ...             ...                   ...  ...      ...      ...
# 71987     movie  I Lost My Body  J'ai perdu mon corps  ...    34081        6
# 71988     movie  I Lost My Body  J'ai perdu mon corps  ...    34081        6
# 71989     movie  I Lost My Body  J'ai perdu mon corps  ...    34081        6
# 71990     movie  I Lost My Body  J'ai perdu mon corps  ...    34081        6
# 71991     movie  I Lost My Body  J'ai perdu mon corps  ...    34081        6
#
#           nconst         category                      job        primaryName  \
# 0      nm0504380  cinematographer                      NaN      Elgin Lessley
# 1      nm0504380  cinematographer                      NaN      Elgin Lessley
# 2      nm0504380  cinematographer                      NaN      Elgin Lessley
# 3      nm0504380  cinematographer                      NaN      Elgin Lessley
# 4      nm0504380  cinematographer                      NaN      Elgin Lessley
# ...          ...              ...                      ...                ...
# 71987  nm0491011           writer  adaptation and dialogue  Guillaume Laurant
# 71988  nm0491011           writer  adaptation and dialogue  Guillaume Laurant
# 71989  nm0491011           writer  adaptation and dialogue  Guillaume Laurant
# 71990  nm0491011           writer  adaptation and dialogue  Guillaume Laurant
# 71991  nm0491011           writer  adaptation and dialogue  Guillaume Laurant
#
#        birthYear  deathYear primaryProfession knownForTitles
# 0           1883       1944   cinematographer      tt0016332
# 1           1883       1944   cinematographer      tt0015163
# 2           1883       1944   cinematographer      tt0014341
# 3           1883       1944   cinematographer      tt0015324
# 4           1883       1944             actor      tt0016332
# ...          ...        ...               ...            ...
# 71987       1961       <NA>            writer      tt0344510
# 71988       1961       <NA>             actor      tt1149361
# 71989       1961       <NA>             actor      tt0211915
# 71990       1961       <NA>             actor      tt9806192
# 71991       1961       <NA>             actor      tt0344510
#
# [71992 rows x 26 columns]

# %%
# reformat staff age data into 1 column and make columns from the categories
staff = raw_film_data.loc[:,['tconst','nconst','category','primaryName','birthYear','deathYear']].drop_duplicates()
staff.loc[:,'printname'] = staff.loc[:,'primaryName'] + " " + staff.loc[:,'birthYear'].astype('str') + ' - ' + staff.loc[:,'deathYear'].astype(str)
staff.drop(['nconst','primaryName','birthYear','deathYear'], axis=1, inplace=True)
staff = staff.groupby(['tconst','category'])['printname'].aggregate(lambda x: tuple(x)).unstack()
staff.drop(['archive_footage','self','production_designer'], axis=1, inplace=True)
staff
# Out:
# category                                               actor  \
# tconst
# tt0015324  (Buster Keaton 1895 - 1966, Joe Keaton 1867 - ...
# tt0017136  (Alfred Abel 1879 - 1937, Gustav Fröhlich 1902...
# tt0022100  (Peter Lorre 1904 - 1964, Otto Wernicke 1893 -...
# tt0025316  (Jameson Thomas 1888 - 1939, Clark Gable 1901 ...
# tt0031381  (Clark Gable 1901 - 1960, Thomas Mitchell 1892...
# ...                                                      ...
# tt9691136  (Nick Robinson 1995 - <NA>, Beulah Koale <NA> ...
# tt9731598  (Billy Eichner 1978 - <NA>, Luke Macfarlane 19...
# tt9764362  (Ralph Fiennes 1962 - <NA>, Nicholas Hoult 198...
# tt9783600  (Chris Hemsworth 1983 - <NA>, Miles Teller 198...
# tt9806192  (Hakim Faris <NA> - <NA>, Patrick d'Assumçao <...
#
# category                                             actress  \
# tconst
# tt0015324                     (Kathryn McGuire 1903 - 1978,)
# tt0017136                       (Brigitte Helm 1906 - 1996,)
# tt0022100  (Ellen Widmann 1894 - 1985, Inge Landgut 1922 ...
# tt0025316                   (Claudette Colbert 1903 - 1996,)
# tt0031381  (Vivien Leigh 1913 - 1967, Barbara O'Neil 1910...
# ...                                                      ...
# tt9691136                  (Chloë Grace Moretz 1997 - <NA>,)
# tt9731598                                                NaN
# tt9764362  (Anya Taylor-Joy 1996 - <NA>, Hong Chau 1979 -...
# tt9783600                     (Jurnee Smollett 1986 - <NA>,)
# tt9806192                    (Victoire Du Bois <NA> - <NA>,)
#
# category                                     cinematographer  \
# tconst
# tt0015324  (Elgin Lessley 1883 - 1944, Byron Houck 1891 -...
# tt0017136                                                NaN
# tt0022100                   (Fritz Arno Wagner 1894 - 1958,)
# tt0025316                       (Joseph Walker 1892 - 1985,)
# tt0031381                                                NaN
# ...                                                      ...
# tt9691136                                                NaN
# tt9731598                       (Brandon Trost 1981 - <NA>,)
# tt9764362                                                NaN
# tt9783600                                                NaN
# tt9806192                                                NaN
#
# category                                            composer  \
# tconst
# tt0015324                 (Club Foot Orchestra <NA> - <NA>,)
# tt0017136  (Sandro Forte 1970 - 2020, Maximianno Cobra 19...
# tt0022100                                                NaN
# tt0025316                                                NaN
# tt0031381                                                NaN
# ...                                                      ...
# tt9691136                                                NaN
# tt9731598                        (Marc Shaiman 1959 - <NA>,)
# tt9764362                                                NaN
# tt9783600                                                NaN
# tt9806192                            (Dan Levy 1976 - <NA>,)
#
# category                                            director  \
# tconst
# tt0015324                       (Buster Keaton 1895 - 1966,)
# tt0017136                          (Fritz Lang 1890 - 1976,)
# tt0022100                          (Fritz Lang 1890 - 1976,)
# tt0025316                         (Frank Capra 1897 - 1991,)
# tt0031381  (Victor Fleming 1889 - 1949, George Cukor 1899...
# ...                                                      ...
# tt9691136                      (Roseanne Liang <NA> - <NA>,)
# tt9731598                    (Nicholas Stoller 1976 - <NA>,)
# tt9764362                          (Mark Mylod <NA> - <NA>,)
# tt9783600                     (Joseph Kosinski 1974 - <NA>,)
# tt9806192                       (Jérémy Clapin 1974 - <NA>,)
#
# category                              editor  \
# tconst
# tt0015324                                NaN
# tt0017136                                NaN
# tt0022100     (Paul Falkenberg 1903 - 1986,)
# tt0025316        (Gene Havlick 1894 - 1959,)
# tt0031381                                NaN
# ...                                      ...
# tt9691136                                NaN
# tt9731598        (Daniel Gabbe <NA> - <NA>,)
# tt9764362                                NaN
# tt9783600                                NaN
# tt9806192  (Benjamin Massoubre <NA> - <NA>,)
#
# category                                            producer  \
# tconst
# tt0015324                                                NaN
# tt0017136                        (Erich Pommer 1889 - 1966,)
# tt0022100                                                NaN
# tt0025316                                                NaN
# tt0031381                                                NaN
# ...                                                      ...
# tt9691136  (Kelly McCormick 1977 - <NA>, Fred Berger <NA>...
# tt9731598  (Judd Apatow 1967 - <NA>, Josh Church <NA> - <...
# tt9764362  (Betsy Koch <NA> - <NA>, Will Ferrell 1967 - <...
# tt9783600  (Tommy Harper <NA> - <NA>, Agnes Chu <NA> - <NA>)
# tt9806192                   (Marc Du Pontavice <NA> - <NA>,)
#
# category                                              writer
# tconst
# tt0015324  (Jean C. Havez 1872 - 1925, Joseph A. Mitchell...
# tt0017136  (Thea von Harbou 1888 - 1954, Fritz Lang 1890 ...
# tt0022100  (Thea von Harbou 1888 - 1954, Fritz Lang 1890 ...
# tt0025316  (Robert Riskin 1897 - 1955, Samuel Hopkins Ada...
# tt0031381  (Margaret Mitchell 1900 - 1949, Sidney Howard ...
# ...                                                      ...
# tt9691136  (Max Landis 1985 - <NA>, Roseanne Liang <NA> -...
# tt9731598  (Billy Eichner 1978 - <NA>, Nicholas Stoller 1...
# tt9764362   (Seth Reiss <NA> - <NA>, Will Tracy <NA> - <NA>)
# tt9783600  (George Saunders <NA> - <NA>, Rhett Reese <NA>...
# tt9806192  (Jérémy Clapin 1974 - <NA>, Guillaume Laurant ...
#
# [617 rows x 8 columns]

# %%
# make all genres into columns for easy filtering in excel
genres = raw_film_data.loc[:,['tconst','genres']].drop_duplicates()
genres.genres = genres.genres.str.split(',')
genres = genres.explode('genres')
genres['value'] = 1
genres = pd.pivot_table(genres.explode('genres'), values='value', index='tconst', columns='genres', fill_value=0)
genres
# Out:
# genres     Action  Adventure  Animation  Biography  Comedy  Crime  \
# tconst
# tt0015324       1          0          0          0       1      0
# tt0017136       0          0          0          0       0      0
# tt0022100       0          0          0          0       0      1
# tt0025316       0          0          0          0       1      0
# tt0031381       0          0          0          0       0      0
# ...           ...        ...        ...        ...     ...    ...
# tt9691136       1          0          0          0       0      0
# tt9731598       0          0          0          0       1      0
# tt9764362       0          0          0          0       0      0
# tt9783600       1          0          0          0       0      1
# tt9806192       0          0          1          0       0      0
#
# genres     Documentary  Drama  Family  Fantasy  ...  Music  Musical  Mystery  \
# tconst                                          ...
# tt0015324            0      0       0        0  ...      0        0        0
# tt0017136            0      1       0        0  ...      0        0        0
# tt0022100            0      0       0        0  ...      0        0        1
# tt0025316            0      0       0        0  ...      0        0        0
# tt0031381            0      1       0        0  ...      0        0        0
# ...                ...    ...     ...      ...  ...    ...      ...      ...
# tt9691136            0      0       0        0  ...      0        0        0
# tt9731598            0      0       0        0  ...      0        0        0
# tt9764362            0      0       0        0  ...      0        0        0
# tt9783600            0      1       0        0  ...      0        0        0
# tt9806192            0      1       0        1  ...      0        0        0
#
# genres     Romance  Sci-Fi  Short  Sport  Thriller  War  Western
# tconst
# tt0015324        1       0      0      0         0    0        0
# tt0017136        0       1      0      0         0    0        0
# tt0022100        0       0      0      0         1    0        0
# tt0025316        1       0      0      0         0    0        0
# tt0031381        1       0      0      0         0    1        0
# ...            ...     ...    ...    ...       ...  ...      ...
# tt9691136        0       0      0      0         0    1        0
# tt9731598        1       0      0      0         0    0        0
# tt9764362        0       0      0      0         1    0        0
# tt9783600        0       0      0      0         0    0        0
# tt9806192        0       0      0      0         0    0        0
#
# [617 rows x 23 columns]

# %%
# remove old data and add new data to the movies
readable_data = raw_film_data.copy()
readable_data.drop(['isAdult','ordering', 'nconst','category','job','primaryName','birthYear','deathYear', 'genres','endYear','primaryProfession', 'knownForTitles'], axis=1, inplace=True)
readable_data.drop_duplicates(inplace=True)
readable_data = pd.merge(readable_data, genres, on="tconst", how="left")
readable_data = pd.merge(readable_data, staff, on="tconst", how="left")
readable_data.loc[:,'watched'] = readable_data.loc[:,'watched'].replace(True,1).replace(False,0)
readable_data
# readable_data.sort_values(by=['watched', 'averageRating'], ascending=False).to_excel(output_path, index=False)
# Out:
#         tconst  watched watched_date  netflix  prime  enjoyment  priority  \
# 0    tt0015324        0          NaT     <NA>   <NA>        NaN       NaN
# 1    tt0017136        0          NaT        0      0        NaN       NaN
# 2    tt0022100        0          NaT        0      0        NaN       NaN
# 3    tt0025316        0          NaT     <NA>   <NA>        NaN       NaN
# 4    tt0031381        0          NaT     <NA>   <NA>        NaN       NaN
# ..         ...      ...          ...      ...    ...        ...       ...
# 612  tt9691136        0          NaT        0      0        NaN       NaN
# 613  tt9731598        0          NaT        0      0        NaN       NaN
# 614  tt9764362        1          NaT        0      0        4.0       NaN
# 615  tt9783600        1          NaT     <NA>   <NA>        4.0       NaN
# 616  tt9806192        1          NaT     <NA>   <NA>        4.0       NaN
#
#     titleType           primaryTitle                      originalTitle  ...  \
# 0       movie           Sherlock Jr.                       Sherlock Jr.  ...
# 1       movie             Metropolis                         Metropolis  ...
# 2       movie                      M  M - Eine Stadt sucht einen Mörder  ...
# 3       movie  It Happened One Night              It Happened One Night  ...
# 4       movie     Gone with the Wind                 Gone with the Wind  ...
# ..        ...                    ...                                ...  ...
# 612     movie    Shadow in the Cloud                Shadow in the Cloud  ...
# 613     movie                   Bros                               Bros  ...
# 614     movie               The Menu                           The Menu  ...
# 615     movie             Spiderhead                         Spiderhead  ...
# 616     movie         I Lost My Body               J'ai perdu mon corps  ...
#
#     War Western                                              actor  \
# 0     0       0  (Buster Keaton 1895 - 1966, Joe Keaton 1867 - ...
# 1     0       0  (Alfred Abel 1879 - 1937, Gustav Fröhlich 1902...
# 2     0       0  (Peter Lorre 1904 - 1964, Otto Wernicke 1893 -...
# 3     0       0  (Jameson Thomas 1888 - 1939, Clark Gable 1901 ...
# 4     1       0  (Clark Gable 1901 - 1960, Thomas Mitchell 1892...
# ..   ..     ...                                                ...
# 612   1       0  (Nick Robinson 1995 - <NA>, Beulah Koale <NA> ...
# 613   0       0  (Billy Eichner 1978 - <NA>, Luke Macfarlane 19...
# 614   0       0  (Ralph Fiennes 1962 - <NA>, Nicholas Hoult 198...
# 615   0       0  (Chris Hemsworth 1983 - <NA>, Miles Teller 198...
# 616   0       0  (Hakim Faris <NA> - <NA>, Patrick d'Assumçao <...
#
#                                                actress  \
# 0                       (Kathryn McGuire 1903 - 1978,)
# 1                         (Brigitte Helm 1906 - 1996,)
# 2    (Ellen Widmann 1894 - 1985, Inge Landgut 1922 ...
# 3                     (Claudette Colbert 1903 - 1996,)
# 4    (Vivien Leigh 1913 - 1967, Barbara O'Neil 1910...
# ..                                                 ...
# 612                  (Chloë Grace Moretz 1997 - <NA>,)
# 613                                                NaN
# 614  (Anya Taylor-Joy 1996 - <NA>, Hong Chau 1979 -...
# 615                     (Jurnee Smollett 1986 - <NA>,)
# 616                    (Victoire Du Bois <NA> - <NA>,)
#
#                                        cinematographer  \
# 0    (Elgin Lessley 1883 - 1944, Byron Houck 1891 -...
# 1                                                  NaN
# 2                     (Fritz Arno Wagner 1894 - 1958,)
# 3                         (Joseph Walker 1892 - 1985,)
# 4                                                  NaN
# ..                                                 ...
# 612                                                NaN
# 613                       (Brandon Trost 1981 - <NA>,)
# 614                                                NaN
# 615                                                NaN
# 616                                                NaN
#
#                                               composer  \
# 0                   (Club Foot Orchestra <NA> - <NA>,)
# 1    (Sandro Forte 1970 - 2020, Maximianno Cobra 19...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 612                                                NaN
# 613                        (Marc Shaiman 1959 - <NA>,)
# 614                                                NaN
# 615                                                NaN
# 616                            (Dan Levy 1976 - <NA>,)
#
#                                               director  \
# 0                         (Buster Keaton 1895 - 1966,)
# 1                            (Fritz Lang 1890 - 1976,)
# 2                            (Fritz Lang 1890 - 1976,)
# 3                           (Frank Capra 1897 - 1991,)
# 4    (Victor Fleming 1889 - 1949, George Cukor 1899...
# ..                                                 ...
# 612                      (Roseanne Liang <NA> - <NA>,)
# 613                    (Nicholas Stoller 1976 - <NA>,)
# 614                          (Mark Mylod <NA> - <NA>,)
# 615                     (Joseph Kosinski 1974 - <NA>,)
# 616                       (Jérémy Clapin 1974 - <NA>,)
#
#                                 editor  \
# 0                                  NaN
# 1                                  NaN
# 2       (Paul Falkenberg 1903 - 1986,)
# 3          (Gene Havlick 1894 - 1959,)
# 4                                  NaN
# ..                                 ...
# 612                                NaN
# 613        (Daniel Gabbe <NA> - <NA>,)
# 614                                NaN
# 615                                NaN
# 616  (Benjamin Massoubre <NA> - <NA>,)
#
#                                               producer  \
# 0                                                  NaN
# 1                          (Erich Pommer 1889 - 1966,)
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 612  (Kelly McCormick 1977 - <NA>, Fred Berger <NA>...
# 613  (Judd Apatow 1967 - <NA>, Josh Church <NA> - <...
# 614  (Betsy Koch <NA> - <NA>, Will Ferrell 1967 - <...
# 615  (Tommy Harper <NA> - <NA>, Agnes Chu <NA> - <NA>)
# 616                   (Marc Du Pontavice <NA> - <NA>,)
#
#                                                 writer
# 0    (Jean C. Havez 1872 - 1925, Joseph A. Mitchell...
# 1    (Thea von Harbou 1888 - 1954, Fritz Lang 1890 ...
# 2    (Thea von Harbou 1888 - 1954, Fritz Lang 1890 ...
# 3    (Robert Riskin 1897 - 1955, Samuel Hopkins Ada...
# 4    (Margaret Mitchell 1900 - 1949, Sidney Howard ...
# ..                                                 ...
# 612  (Max Landis 1985 - <NA>, Roseanne Liang <NA> -...
# 613  (Billy Eichner 1978 - <NA>, Nicholas Stoller 1...
# 614   (Seth Reiss <NA> - <NA>, Will Tracy <NA> - <NA>)
# 615  (George Saunders <NA> - <NA>, Rhett Reese <NA>...
# 616  (Jérémy Clapin 1974 - <NA>, Guillaume Laurant ...
#
# [617 rows x 45 columns]
